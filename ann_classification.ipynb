# %% [markdown]
# # ANN Classification TensorFlow 2
#
# MNIST Classification example

# %% [markdown]
# ## Load Packages

# %%
import tensorflow as tf

# %% [markdown]
# ## Load Data

# %%
mnist = tf.keras.datasets.mnist
(X_train,y_train),(X_test,y_test) = mnist.load_data()
X_train, X_test = X_train/255.0 , X_test/255.0
print(X_train.shape, y_train.shape)
# Out:
# (60000, 28, 28) (60000,)

# %% [markdown]
# ## Build Model

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

# %% [markdown]
# ## Train

# %%
r = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2978 - accuracy: 0.9138 - val_loss: 0.1429 - val_accuracy: 0.9572
# Epoch 2/10
# 1875/1875 [==============================] - 2s 978us/step - loss: 0.1458 - accuracy: 0.9563 - val_loss: 0.1019 - val_accuracy: 0.9678
# Epoch 3/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.1086 - accuracy: 0.9658 - val_loss: 0.0819 - val_accuracy: 0.9751
# Epoch 4/10
# 1875/1875 [==============================] - 2s 953us/step - loss: 0.0884 - accuracy: 0.9730 - val_loss: 0.0833 - val_accuracy: 0.9747
# Epoch 5/10
# 1875/1875 [==============================] - 2s 973us/step - loss: 0.0759 - accuracy: 0.9766 - val_loss: 0.0722 - val_accuracy: 0.9778
# Epoch 6/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0643 - accuracy: 0.9795 - val_loss: 0.0689 - val_accuracy: 0.9802
# Epoch 7/10
# 1875/1875 [==============================] - 2s 988us/step - loss: 0.0599 - accuracy: 0.9812 - val_loss: 0.0673 - val_accuracy: 0.9800
# Epoch 8/10
# 1875/1875 [==============================] - 2s 947us/step - loss: 0.0513 - accuracy: 0.9839 - val_loss: 0.0707 - val_accuracy: 0.9785
# Epoch 9/10
# 1875/1875 [==============================] - 2s 978us/step - loss: 0.0490 - accuracy: 0.9839 - val_loss: 0.0647 - val_accuracy: 0.9810
# Epoch 10/10
# 1875/1875 [==============================] - 2s 941us/step - loss: 0.0457 - accuracy: 0.9852 - val_loss: 0.0633 - val_accuracy: 0.9807

# %%
# plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='Loss')
plt.plot(r.history['val_loss'], label='Validation Loss')
plt.legend();

# %%
# plot accuracy per iteration
plt.plot(r.history['accuracy'], label='Accuracy')
plt.plot(r.history['val_accuracy'], label='Validation Accuracy')
plt.legend();

# %%
# show a random misclassified example
